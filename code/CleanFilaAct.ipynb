# %% [markdown]
# # Clean Strava file
#
# This notebook is used to clean the Strava file. It rewrites the file **strava_ips.xlsx**. It performs the following operations:
# * Delete the rows with more than 50% of missing.
# * Clean dates to read with Looker Studio. Google sheets does not recognize the date format.
# * Clean white spaces in the columns.
# * Convert the numeric columns so that they are recognized as numbers in Looker Studio.
#
# The data in the file strava_ips.xlsx should be copied to the Google sheet **Strava_IPS**.
# * Open your Google drive in your working directory. Here you will get your Google sheet.
# * Copy the file strava_ips.xlsx in the above directory.
# * Open the Excel file in the drive. Copy and paste the data to the Google sheet Strava_IPS.

# %% [markdown]
# ## Read file

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Open file activities.csv
df0 = pd.read_csv('../data/activities.csv')
df0.tail(3)
# Out:
#       Id. de actividad  Fecha de la actividad Nombre de la actividad  \
# 2620       15082470006  11 jul. 2025 16:07:38               Nissan 2
# 2621       15091449603  12 jul. 2025 13:35:53     Presa El Mastranto
# 2622       15106139815  13 jul. 2025 18:57:08   Central de autobuses
#
#      Tipo de actividad Descripción de la actividad  Tiempo transcurrido  \
# 2620          Caminata              Aguascalientes                15918
# 2621   Vuelta ciclista                         NaN                10109
# 2622   Vuelta ciclista                   Zacatecas                 1464
#
#       Distancia  Ritmo cardíaco máx.  Esfuerzo relativo  Viaje al trabajo  \
# 2620      23.41                  NaN                NaN             False
# 2621      40.97                147.0               33.0             False
# 2622       5.14                152.0               20.0             False
#
#      Nota privada de actividad Equipamiento de la actividad  \
# 2620                       NaN        Skechers Squad 232290
# 2621                       NaN             Trek X-Caliber 9
# 2622                       NaN             Trek X-Caliber 9
#
#                   Nombre de archivo  Peso del atleta  Peso de la bicicleta  \
# 2620     activities/15082470006.gpx              NaN                   NaN
# 2621  activities/16113281376.fit.gz              NaN                  14.5
# 2622  activities/16129436693.fit.gz              NaN                  14.5
#
#       Tiempo transcurrido.1  Tiempo en movimiento   Distancia.1  \
# 2620                15918.0               15511.0  23409.300781
# 2621                10109.0                8651.0  40978.000000
# 2622                 1464.0                1429.0   5141.399902
#
#       Velocidad máxima  Velocidad promedio  Desnivel positivo  \
# 2620              7.16            1.509206          83.825684
# 2621             11.53            4.736794         366.537292
# 2622              7.92            3.597901         174.076370
#
#       Desnivel negativo  Desnivel bajo  Desnivel alto  Grado máximo  \
# 2620          62.880806    1858.400024    1890.000000     39.393940
# 2621         502.000000    2238.000000    2480.199951     24.799999
# 2622         138.000000    2323.899902    2473.699951     31.250000
#
#       Pendiente promedio  Grado positivo promedio  Grado negativo promedio  \
# 2620            0.090562                      NaN                      NaN
# 2621           -0.002196                      NaN                      NaN
# 2622            2.567394                      NaN                      NaN
#
#       Cadencia máx.  Cadencia promedio  Ritmo cardíaco máx..1  \
# 2620            NaN                NaN                    NaN
# 2621            NaN                NaN                  147.0
# 2622            NaN                NaN                  152.0
#
#       Ritmo cardíaco promedio  Máx. de vatios  Vatios promedio     Calorías  \
# 2620                      NaN             NaN              NaN  2272.240479
# 2621               105.381279             NaN        64.967407   892.000000
# 2622               133.165482             NaN       139.644913   267.000000
#
#       Temperatura máx.  Temperatura promedio  Esfuerzo relativo.1  \
# 2620               NaN                   NaN                  NaN
# 2621               NaN                   NaN                 33.0
# 2622               NaN                   NaN                 20.0
#
#       Esfuerzo total  Cantidad de carreras  Tiempo de ascenso  \
# 2620             NaN                   NaN                NaN
# 2621             NaN                   NaN                NaN
# 2622             NaN                   NaN                NaN
#
#       Tiempo de descenso  Otro tiempo  Esfuerzo Percibido  Tipo  \
# 2620                 NaN          NaN                 NaN   NaN
# 2621                 NaN          NaN                 NaN   NaN
# 2622                 NaN          NaN                 NaN   NaN
#
#       Hora de inicio  Potencia promedio ponderada  Conteo de potencia  \
# 2620             NaN                          NaN                 NaN
# 2621             NaN                          NaN                 NaN
# 2622             NaN                          NaN                 NaN
#
#       Usar Esfuerzo Percibido  Esfuerzo relativo percibido  \
# 2620                      0.0                          NaN
# 2621                      0.0                          NaN
# 2622                      0.0                          NaN
#
#       Viaje al trabajo.1  Peso total levantado  De carga  \
# 2620                 0.0                   NaN       1.0
# 2621                 0.0                   NaN       1.0
# 2622                 0.0                   NaN       1.0
#
#       Distancia ajustada en pendientes  Tiempo de observación del clima  \
# 2620                               NaN                              NaN
# 2621                               NaN                              NaN
# 2622                               NaN                              NaN
#
#       Condición climática  Temperatura  Sensación térmica  Punto de rocío  \
# 2620                  NaN          NaN                NaN             NaN
# 2621                  NaN          NaN                NaN             NaN
# 2622                  NaN          NaN                NaN             NaN
#
#       Humedad  Presión atmosférica  Velocidad del viento  Ráfaga de viento  \
# 2620      NaN                  NaN                   NaN               NaN
# 2621      NaN                  NaN                   NaN               NaN
# 2622      NaN                  NaN                   NaN               NaN
#
#       Dirección del viento  Intensidad de la precipitación  \
# 2620                   NaN                             NaN
# 2621                   NaN                             NaN
# 2622                   NaN                             NaN
#
#       Hora de salida del sol  Hora de puesta del sol  Fase lunar  Bicicleta  \
# 2620                     NaN                     NaN         NaN        NaN
# 2621                     NaN                     NaN         NaN  5230367.0
# 2622                     NaN                     NaN         NaN  5230367.0
#
#       Equipamiento  Probabilidad de precipitación  Tipo de precipitación  \
# 2620    13682437.0                            NaN                    NaN
# 2621           NaN                            NaN                    NaN
# 2622           NaN                            NaN                    NaN
#
#       Nubosidad  Visibilidad  Índice UV  Estado del ozono  Recuento de saltos  \
# 2620        NaN          NaN        NaN               NaN                 NaN
# 2621        NaN          NaN        NaN               NaN                 NaN
# 2622        NaN          NaN        NaN               NaN                 NaN
#
#       Complejidad total  Fluidez promedio  Marcado  \
# 2620                NaN               NaN      0.0
# 2621                NaN               NaN      0.0
# 2622                NaN               NaN      0.0
#
#       Velocidad promedio durante el tiempo transcurrido  \
# 2620                                           1.470618
# 2621                                           4.053616
# 2622                                           3.511885
#
#       Distancia sobre tierra  Distancia recién recorrida  \
# 2620             1224.599976                         NaN
# 2621            13585.700195                         NaN
# 2622             2839.899902                         NaN
#
#       Distancia recién recorrida en caminos sin asfaltar  \
# 2620                                                NaN
# 2621                                                NaN
# 2622                                                NaN
#
#       Número de actividades  Pasos en total  Emisión de carbono evitada  \
# 2620                    NaN         27390.0                         NaN
# 2621                    NaN             NaN                         NaN
# 2622                    NaN             NaN                         NaN
#
#       Largo de la piscina  Carga de entrenamiento  Intensidad  \
# 2620                  NaN                     NaN         NaN
# 2621                  NaN                     NaN         NaN
# 2622                  NaN                     NaN         NaN
#
#       Ritmo ajustado en pendientes promedio  Tiempo del cronómetro  \
# 2620                                    NaN                    NaN
# 2621                                    NaN                    NaN
# 2622                                    NaN                    NaN
#
#       Ciclos en total                                         Multimedia
# 2620              NaN                                                NaN
# 2621              NaN  media/5301D6B4-6BDD-4A22-B4C5-C77F6753DC35.jpg...
# 2622              NaN                                                NaN

# %% [markdown]
# ## Delete half empty columns

# %%
# Count missing values in each column. Sort from highest to lowest.
missing_values = df0.isnull().sum().sort_values(ascending=False)
missing_values
# Out:
# Grado negativo promedio                               2623
# Grado positivo promedio                               2623
# Hora de puesta del sol                                2623
# Fase lunar                                            2623
# Tipo de precipitación                                 2623
# Probabilidad de precipitación                         2623
# Índice UV                                             2623
# Estado del ozono                                      2623
# Tiempo de observación del clima                       2623
# Condición climática                                   2623
# Velocidad del viento                                  2623
# Presión atmosférica                                   2623
# Humedad                                               2623
# Punto de rocío                                        2623
# Potencia promedio ponderada                           2623
# Conteo de potencia                                    2623
# Esfuerzo relativo percibido                           2623
# Peso total levantado                                  2623
# Sensación térmica                                     2623
# Temperatura                                           2623
# Hora de inicio                                        2623
# Tipo                                                  2623
# Esfuerzo total                                        2623
# Cantidad de carreras                                  2623
# Tiempo de ascenso                                     2623
# Tiempo de descenso                                    2623
# Otro tiempo                                           2623
# Esfuerzo Percibido                                    2623
# Temperatura máx.                                      2623
# Máx. de vatios                                        2623
# Ciclos en total                                       2623
# Intensidad                                            2623
# Distancia recién recorrida en caminos sin asfaltar    2623
# Distancia recién recorrida                            2623
# Tiempo del cronómetro                                 2623
# Largo de la piscina                                   2623
# Carga de entrenamiento                                2623
# Fluidez promedio                                      2623
# Recuento de saltos                                    2623
# Complejidad total                                     2623
# Nubosidad                                             2623
# Visibilidad                                           2623
# Número de actividades                                 2623
# Intensidad de la precipitación                        2623
# Dirección del viento                                  2623
# Ráfaga de viento                                      2623
# Hora de salida del sol                                2623
# Nota privada de actividad                             2622
# Ritmo ajustado en pendientes promedio                 2597
# Multimedia                                            2487
# Distancia ajustada en pendientes                      2478
# Pasos en total                                        2313
# Cadencia máx.                                         2309
# Cadencia promedio                                     2309
# Emisión de carbono evitada                            2177
# Descripción de la actividad                           2133
# Temperatura promedio                                  2112
# Equipamiento                                          2011
# Peso del atleta                                       1991
# Ritmo cardíaco máx..1                                 1452
# Ritmo cardíaco promedio                                819
# Marcado                                                791
# Ritmo cardíaco máx.                                    783
# Esfuerzo relativo                                      783
# Esfuerzo relativo.1                                    783
# Velocidad promedio durante el tiempo transcurrido      775
# De carga                                               623
# Vatios promedio                                        611
# Peso de la bicicleta                                   610
# Velocidad promedio                                     606
# Bicicleta                                              606
# Usar Esfuerzo Percibido                                576
# Distancia sobre tierra                                 440
# Desnivel negativo                                      122
# Viaje al trabajo.1                                      59
# Desnivel alto                                           42
# Desnivel bajo                                           42
# Nombre de archivo                                       37
# Desnivel positivo                                       37
# Grado máximo                                            37
# Velocidad máxima                                        37
# Calorías                                                22
# Tiempo transcurrido.1                                   21
# Equipamiento de la actividad                             3
# Pendiente promedio                                       0
# Tiempo en movimiento                                     0
# Nombre de la actividad                                   0
# Tiempo transcurrido                                      0
# Distancia.1                                              0
# Fecha de la actividad                                    0
# Id. de actividad                                         0
# Tipo de actividad                                        0
# Viaje al trabajo                                         0
# Distancia                                                0
# dtype: int64

# %%
# Drop columns with 50% missing values, but keep 'Descripción de la actividad'
cols_to_keep = ['Descripción de la actividad']
cols_above_thresh = df0.dropna(thresh=df0.shape[0]*0.5, axis=1).columns.tolist()
cols_final = [col for col in df0.columns if col in cols_above_thresh or col in cols_to_keep]
df1 = df0[cols_final]

# Count missing values in each column. Sort from highest to lowest.
missing_values = df1.isnull().sum().sort_values(ascending=False)
missing_values
# Out:
# Descripción de la actividad                          2133
# Ritmo cardíaco promedio                               819
# Marcado                                               791
# Esfuerzo relativo                                     783
# Esfuerzo relativo.1                                   783
# Ritmo cardíaco máx.                                   783
# Velocidad promedio durante el tiempo transcurrido     775
# De carga                                              623
# Vatios promedio                                       611
# Peso de la bicicleta                                  610
# Velocidad promedio                                    606
# Bicicleta                                             606
# Usar Esfuerzo Percibido                               576
# Distancia sobre tierra                                440
# Desnivel negativo                                     122
# Viaje al trabajo.1                                     59
# Desnivel alto                                          42
# Desnivel bajo                                          42
# Velocidad máxima                                       37
# Desnivel positivo                                      37
# Grado máximo                                           37
# Nombre de archivo                                      37
# Calorías                                               22
# Tiempo transcurrido.1                                  21
# Equipamiento de la actividad                            3
# Id. de actividad                                        0
# Fecha de la actividad                                   0
# Nombre de la actividad                                  0
# Tiempo en movimiento                                    0
# Distancia.1                                             0
# Viaje al trabajo                                        0
# Distancia                                               0
# Tiempo transcurrido                                     0
# Tipo de actividad                                       0
# Pendiente promedio                                      0
# dtype: int64

# %%
df1.tail()
# Out:
#       Id. de actividad  Fecha de la actividad Nombre de la actividad  \
# 2618       15062070140   9 jul. 2025 18:37:11              Guadalupe
# 2619       15064232066  10 jul. 2025 00:48:39       Zacatecas Centro
# 2620       15082470006  11 jul. 2025 16:07:38               Nissan 2
# 2621       15091449603  12 jul. 2025 13:35:53     Presa El Mastranto
# 2622       15106139815  13 jul. 2025 18:57:08   Central de autobuses
#
#      Tipo de actividad Descripción de la actividad  Tiempo transcurrido  \
# 2618   Vuelta ciclista                       Pagos                 5816
# 2619          Caminata                   Zacatecas                 8155
# 2620          Caminata              Aguascalientes                15918
# 2621   Vuelta ciclista                         NaN                10109
# 2622   Vuelta ciclista                   Zacatecas                 1464
#
#       Distancia  Ritmo cardíaco máx.  Esfuerzo relativo  Viaje al trabajo  \
# 2618      13.22                128.0                8.0             False
# 2619       7.22                110.0               14.0             False
# 2620      23.41                  NaN                NaN             False
# 2621      40.97                147.0               33.0             False
# 2622       5.14                152.0               20.0             False
#
#      Equipamiento de la actividad              Nombre de archivo  \
# 2618             Trek X-Caliber 9  activities/16080966128.fit.gz
# 2619       Adidas Terrex Eastrail  activities/16083343664.fit.gz
# 2620        Skechers Squad 232290     activities/15082470006.gpx
# 2621             Trek X-Caliber 9  activities/16113281376.fit.gz
# 2622             Trek X-Caliber 9  activities/16129436693.fit.gz
#
#       Peso de la bicicleta  Tiempo transcurrido.1  Tiempo en movimiento  \
# 2618                  14.5                 5816.0                3889.0
# 2619                   NaN                 8155.0                6694.0
# 2620                   NaN                15918.0               15511.0
# 2621                  14.5                10109.0                8651.0
# 2622                  14.5                 1464.0                1429.0
#
#        Distancia.1  Velocidad máxima  Velocidad promedio  Desnivel positivo  \
# 2618  13220.599609          8.600000            3.399486         118.358093
# 2619   7223.500000          4.663636            1.079101          87.697800
# 2620  23409.300781          7.160000            1.509206          83.825684
# 2621  40978.000000         11.530000            4.736794         366.537292
# 2622   5141.399902          7.920000            3.597901         174.076370
#
#       Desnivel negativo  Desnivel bajo  Desnivel alto  Grado máximo  \
# 2618         404.000000    2259.199951    2338.199951     21.348314
# 2619         847.000000    2313.199951    2441.000000     16.875000
# 2620          62.880806    1858.400024    1890.000000     39.393940
# 2621         502.000000    2238.000000    2480.199951     24.799999
# 2622         138.000000    2323.899902    2473.699951     31.250000
#
#       Pendiente promedio  Ritmo cardíaco promedio  Vatios promedio  \
# 2618            0.099844                89.400757        47.686947
# 2619           -0.944141                86.362045              NaN
# 2620            0.090562                      NaN              NaN
# 2621           -0.002196               105.381279        64.967407
# 2622            2.567394               133.165482       139.644913
#
#          Calorías  Esfuerzo relativo.1  Usar Esfuerzo Percibido  \
# 2618   334.000000                  8.0                      0.0
# 2619   551.000000                 14.0                      0.0
# 2620  2272.240479                  NaN                      0.0
# 2621   892.000000                 33.0                      0.0
# 2622   267.000000                 20.0                      0.0
#
#       Viaje al trabajo.1  De carga  Bicicleta  Marcado  \
# 2618                 0.0       1.0  5230367.0      0.0
# 2619                 0.0       1.0        NaN      0.0
# 2620                 0.0       1.0        NaN      0.0
# 2621                 0.0       1.0  5230367.0      0.0
# 2622                 0.0       1.0  5230367.0      0.0
#
#       Velocidad promedio durante el tiempo transcurrido  \
# 2618                                           2.273143
# 2619                                           0.885776
# 2620                                           1.470618
# 2621                                           4.053616
# 2622                                           3.511885
#
#       Distancia sobre tierra
# 2618             8472.799805
# 2619             2593.300049
# 2620             1224.599976
# 2621            13585.700195
# 2622             2839.899902

# %% [markdown]
# ## Parse date

# %%
# Split the column 'Fecha de la actividad' into 4 columns
dfdate = df0['Fecha de la actividad'].str.split(expand=True).rename(columns={0: 'Day', 1: 'Month', 2: 'Year', 3: 'Time'})
# Delete '.' from 'Month' column
dfdate['Month'] = dfdate['Month'].str.replace('.', '')
dfdate['Mont_Num'] = dfdate['Month'].str.replace('ene', '01').str.replace('feb', '02').str.replace('mar', '03').str.replace('abr', '04').str.replace('may', '05').str.replace('jun', '06').str.replace('jul', '07').str.replace('ago', '08').str.replace('sep', '09').str.replace('oct', '10').str.replace('nov', '11').str.replace('dic', '12')
# Convert numeric values to datetime
dfdate['Date'] = pd.to_datetime(dfdate['Year'] + '-' + dfdate['Mont_Num'] + '-' + dfdate['Day'])

# Define an empty dataframe
df1.loc[:,'Fecha de la actividad'] = dfdate['Date']
df1.tail()
# Out:
#       Id. de actividad Fecha de la actividad Nombre de la actividad  \
# 2618       15062070140   2025-07-09 00:00:00              Guadalupe
# 2619       15064232066   2025-07-10 00:00:00       Zacatecas Centro
# 2620       15082470006   2025-07-11 00:00:00               Nissan 2
# 2621       15091449603   2025-07-12 00:00:00     Presa El Mastranto
# 2622       15106139815   2025-07-13 00:00:00   Central de autobuses
#
#      Tipo de actividad Descripción de la actividad  Tiempo transcurrido  \
# 2618   Vuelta ciclista                       Pagos                 5816
# 2619          Caminata                   Zacatecas                 8155
# 2620          Caminata              Aguascalientes                15918
# 2621   Vuelta ciclista                         NaN                10109
# 2622   Vuelta ciclista                   Zacatecas                 1464
#
#       Distancia  Ritmo cardíaco máx.  Esfuerzo relativo  Viaje al trabajo  \
# 2618      13.22                128.0                8.0             False
# 2619       7.22                110.0               14.0             False
# 2620      23.41                  NaN                NaN             False
# 2621      40.97                147.0               33.0             False
# 2622       5.14                152.0               20.0             False
#
#      Equipamiento de la actividad              Nombre de archivo  \
# 2618             Trek X-Caliber 9  activities/16080966128.fit.gz
# 2619       Adidas Terrex Eastrail  activities/16083343664.fit.gz
# 2620        Skechers Squad 232290     activities/15082470006.gpx
# 2621             Trek X-Caliber 9  activities/16113281376.fit.gz
# 2622             Trek X-Caliber 9  activities/16129436693.fit.gz
#
#       Peso de la bicicleta  Tiempo transcurrido.1  Tiempo en movimiento  \
# 2618                  14.5                 5816.0                3889.0
# 2619                   NaN                 8155.0                6694.0
# 2620                   NaN                15918.0               15511.0
# 2621                  14.5                10109.0                8651.0
# 2622                  14.5                 1464.0                1429.0
#
#        Distancia.1  Velocidad máxima  Velocidad promedio  Desnivel positivo  \
# 2618  13220.599609          8.600000            3.399486         118.358093
# 2619   7223.500000          4.663636            1.079101          87.697800
# 2620  23409.300781          7.160000            1.509206          83.825684
# 2621  40978.000000         11.530000            4.736794         366.537292
# 2622   5141.399902          7.920000            3.597901         174.076370
#
#       Desnivel negativo  Desnivel bajo  Desnivel alto  Grado máximo  \
# 2618         404.000000    2259.199951    2338.199951     21.348314
# 2619         847.000000    2313.199951    2441.000000     16.875000
# 2620          62.880806    1858.400024    1890.000000     39.393940
# 2621         502.000000    2238.000000    2480.199951     24.799999
# 2622         138.000000    2323.899902    2473.699951     31.250000
#
#       Pendiente promedio  Ritmo cardíaco promedio  Vatios promedio  \
# 2618            0.099844                89.400757        47.686947
# 2619           -0.944141                86.362045              NaN
# 2620            0.090562                      NaN              NaN
# 2621           -0.002196               105.381279        64.967407
# 2622            2.567394               133.165482       139.644913
#
#          Calorías  Esfuerzo relativo.1  Usar Esfuerzo Percibido  \
# 2618   334.000000                  8.0                      0.0
# 2619   551.000000                 14.0                      0.0
# 2620  2272.240479                  NaN                      0.0
# 2621   892.000000                 33.0                      0.0
# 2622   267.000000                 20.0                      0.0
#
#       Viaje al trabajo.1  De carga  Bicicleta  Marcado  \
# 2618                 0.0       1.0  5230367.0      0.0
# 2619                 0.0       1.0        NaN      0.0
# 2620                 0.0       1.0        NaN      0.0
# 2621                 0.0       1.0  5230367.0      0.0
# 2622                 0.0       1.0  5230367.0      0.0
#
#       Velocidad promedio durante el tiempo transcurrido  \
# 2618                                           2.273143
# 2619                                           0.885776
# 2620                                           1.470618
# 2621                                           4.053616
# 2622                                           3.511885
#
#       Distancia sobre tierra
# 2618             8472.799805
# 2619             2593.300049
# 2620             1224.599976
# 2621            13585.700195
# 2622             2839.899902

# %% [markdown]
# # Clean activity name
#
# To clean the activity name, we perform the following operations:
# * Replace the tag 'Vuelta ciclista' por 'Ciclismo', and filter  only cycling activities.
# * Eliminate extra blank spaces.
# * Replace 'Ciudad de México' by 'CDMX', in case there are both tags.

# %%
# Chage 'Vuelta ciclista' in column 'Tipo de actividad' to 'Ciclismo'
df1.loc[:,'Tipo de actividad'] = df0['Tipo de actividad'].replace('Vuelta ciclista', 'Ciclismo')

# %%
# Copy Id activity column to a new dataframe
dfact = df1.iloc[:, 0:1].copy()
dfact['Tipo de actividad'] = df1['Tipo de actividad']

# Eliminate extra blank spaces at the ends in 'Nombre de la actividad' column
dfact['Activity'] = df0['Nombre de la actividad'].str.strip()
# Clean 'Activity' from special characters. Use only lower letters and numbers.
#dfact['Activity'] = dfact['Activity'].str.replace(' ','_').str.replace('[^a-zA-Z0-9]', '').str.lower()
# Eliminate accentuated characters.
#dfact['Activity'] = dfact['Activity'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
# Replace 'Ciudad de México' with 'CDMX'
dfact['Activity'] = dfact['Activity'].str.replace('Ciudad de México', 'CDMX')
dfact['Activity'].value_counts()
# Out:
# Activity
# Tec de Monterrey                          1068
# Culiacán                                   296
# Las Palmas 2                                75
# Guadalupe                                   68
# CDMX                                        54
# Zacatecas                                   48
# Navolato                                    38
# Arroyo de la Plata                          31
# Aguaruto                                    26
# Ley del Valle                               16
# San Pedro                                   16
# El Limón de los Ramos                       14
# Ley Palmito                                 13
# Aeropuerto                                  13
# Ojocaliente                                 12
# Tolosa                                      12
# La Platanera                                12
# El Batallón                                 11
# Trancoso                                    11
# Tacoaleche                                  11
# Culiacán Centro                             11
# Solar Las Palmas 2                          11
# Vetagrande                                  10
# San Jerónimo                                10
# Central de autobuses                        10
# Costa Rica                                   9
# La Zacatecana                                9
# Infonavit Las Flores                         9
# Altata                                       8
# Plaza Humaya                                 8
# Querétaro                                    8
# El Tamarindo                                 8
# La Paz                                       7
# Industrial El Palmito                        7
# Sauceda de la Borda                          7
# Imala                                        7
# Caseta Salida Norte                          7
# Guadalupe Centro                             7
# Palmira                                      6
# Colonia Anáhuac                              6
# Entronque La Curva                           6
# San Rafael                                   6
# Culiacancito                                 6
# Villa Juárez                                 5
# Plaza Azahares                               5
# Pemex                                        5
# Iguala                                       5
# Plaza Ceiba                                  5
# Guadalupe - Aguascalientes                   4
# Cerro de la Virgen                           4
# Malpaso                                      4
# Malecón de Mazatlán                          4
# Mojolo                                       4
# La Sinaloa                                   4
# El Pinole                                    4
# Parque Lineal Bugambilias                    4
# La Palmita y Anexos                          4
# Canal del Olmo                               4
# Mazatlán                                     4
# Tepechitlán                                  4
# Cieneguitas                                  4
# Home Depot                                   4
# Chihuahua                                    4
# La Noria                                     3
# Los Becos                                    3
# Polanco                                      3
# Santa Mónica                                 3
# Feria Ganadera                               3
# Hospital La Raza                             3
# Jerez                                        3
# Morelos                                      3
# Fresnillo                                    3
# Piedra Gorda                                 3
# Villanueva                                   3
# Plateros                                     3
# Tepetate                                     3
# La Peñita de Jaltemba                        3
# Naucalpan                                    3
# Knoxville Downtown                           3
# La Guamuchilera                              3
# Calera                                       3
# Nuevo Mundo                                  3
# JAPAC                                        3
# Durango                                      3
# Ciclobike                                    3
# Plaza Fiesta                                 3
# El Alhuate                                   3
# La Curva                                     3
# Río Culiacán                                 3
# Estadio Tomateros                            3
# Zacatecas Centro                             3
# Infonavit Barrancos                          3
# Cabo San Lucas                               3
# Bariometo                                    3
# Topolobampo                                  3
# Boulevard Las Torres                         2
# El Palmito - Mazatlán                        2
# Plaza Galerías                               2
# Cieneguillas                                 2
# Caseta Cuauhtémoc-Osiris                     2
# Jesús María                                  2
# Pozo de Gamboa                               2
# Guadalupe - Colotlán                         2
# Ojo de Agua del Progreso                     2
# Los Linces                                   2
# San Luis Potosí                              2
# Xoconostle                                   2
# La Labor                                     2
# San Isidro Bocanegra                         2
# Delia Barraza                                2
# Los Charritos                                2
# Lomas del Boulevard                          2
# Taller Zavala                                2
# Flor de México                               2
# Culiancito                                   2
# Surutato                                     2
# El Quemadito                                 2
# Infovanit Las Flores                         2
# Santa Rocío                                  2
# La Bufa                                      2
# El Salto                                     2
# San Antonio del Ciprés                       2
# Campo Balbuena                               2
# La Cuesta                                    2
# Bugambilias                                  2
# Durango - Suchil                             2
# La Campana                                   2
# Lo de Bartolo                                2
# Los Cascabeles                               2
# Cola de Gato                                 2
# El Pozo                                      2
# Los Agaves                                   2
# Rancho Los Migueles                          2
# Fracc. Viñedos, Querétaro                    2
# Valdez Montoya                               2
# Mercado Guadalupe                            2
# El Salto - Durango                           2
# Bachigualato                                 2
# Dique La Primavera                           2
# Coyoacán                                     2
# Monterrey                                    2
# Yebavito                                     2
# Nuevo Altata                                 2
# El Faro                                      2
# Bearden                                      2
# Tepuche                                      2
# Smoky Mountains                              2
# Best Buy                                     2
# Sequoyah Greenway                            2
# Morningside Park                             2
# Tickle Building                              2
# Caimanero                                    2
# Volunter Hall                                2
# Ejido Convención de Aguascalientes           2
# Los Llamas                                   2
# TAPO                                         1
# Nissan 2                                     1
# Sombrerete - Fresnillo                       1
# Durango - Sombrerete                         1
# Hotel NH San Pedro                           1
# Lay del Valle                                1
# Valle Alto                                   1
# Navolato a El Batallón                       1
# Aurrerá Sanalona                             1
# San Blas                                     1
# Cascadas                                     1
# Lomas de Chapultepec                         1
# Alrededor Torre Pemex                        1
# El árbol de la noche victoriosa              1
# Centro Comercial Diagonal                    1
# CONIN                                        1
# Cofradía de Navolato                         1
# Ojo de Agua de la Palma                      1
# Ojocaliente a Trancoso                       1
# AICM                                         1
# IPN Zacatenco                                1
# Tasty Chicken                                1
# Díaz Ordaz                                   1
# Maratón CDMX                                 1
# Knox Plaza                                   1
# Cherokee Farm                                1
# Lakeshore Park                               1
# Blount Knox Greenway                         1
# Kelton Homes                                 1
# Knox County Health Department                1
# TVB Store                                    1
# Krutch Park                                  1
# Bearden Greenway                             1
# Zona Conurbada                               1
# Bariometo II                                 1
# Walmart CEDIS                                1
# Casetas San Pedro - Costa Rica               1
# Culiacán - Guasave                           1
# Noria de los Gringos                         1
# Cerca Caseta                                 1
# Aguascalientes - León                        1
# León - Celaya                                1
# Celaya - Querétaro                           1
# Guacamayas                                   1
# Metro Revolución                             1
# Viñedos                                      1
# Desviación Chilitas                          1
# INIFAP                                       1
# Deportiva Norte                              1
# El Carmen                                    1
# Knoxville Greenways                          1
# Guadalupe- Momax                             1
# The Shire                                    1
# Estadio Banorte                              1
# Villa Unión                                  1
# K98 - La Paz                                 1
# Villa Unión - Potrerillos                    1
# Potrerillos - El Salto                       1
# Pista Mina Bernabe                           1
# Avenida México                               1
# Carrera de la Plata 21K                      1
# Iguala Centro                                1
# Joyas del Atico                              1
# Los Llanos                                   1
# El Vergel                                    1
# El Carrizal 2                                1
# Planta SuKarne                               1
# La Primavera                                 1
# El Tambor                                    1
# Copper Cellar                                1
# Cerca de Tolosa                              1
# Rodeo Bernardez                              1
# Plaza Carso                                  1
# Hipódromo                                    1
# Tlatelolco                                   1
# Parque Arroyo de la Plata                    1
# Noria de Gringas                             1
# Carrera Atlética Regency Club 21K            1
# Sataya                                       1
# Mexiquillo                                   1
# El Palmito                                   1
# Santa Lucía                                  1
# Real del Catorce                             1
# Moctezuma - Estación Wadley                  1
# Noria de los Gringos Tacoaleche              1
# Presa Bicentenario                           1
# El Salto - Concordia                         1
# Avenida Clouthier                            1
# La Cortada                                   1
# Antonio R. Vela                              1
# Cruce Cd. Cuauhtemoc - Genaro Codina         1
# Mazatlán - El Palmito                        1
# Las Higueras                                 1
# Cascada escondida                            1
# San Pedro Garza García                       1
# Agua Caliente de los Monzón                  1
# La Reforma                                   1
# Badiraguato                                  1
# Juan M. Zambada                              1
# Dautillos                                    1
# Toreo                                        1
# Luis Moya                                    1
# Ojuelos                                      1
# Guadalupe - Ojuelos                          1
# Ojuelos - Dolores Hidalgo                    1
# Dolores Hidalgo - Querétaro                  1
# Querétaro - San Juan del Río                 1
# Guadalupe- Aguascalientes                    1
# Guadalupe - Pinos                            1
# Moctezuma - San Antonio de Coronados         1
# San Antonio de Coronados - Matehuala         1
# Constituyentes                               1
# Zacacoyuca                                   1
# Portezuelo                                   1
# Las Brisas                                   1
# Felipe Ángeles                               1
# Concordia - El Palmito                       1
# El Palmito - El Salto                        1
# El Fuerte                                    1
# Villanueva - Tlaltenango                     1
# La Capilla                                   1
# Esteban San Castorena                        1
# San Pedro Piedra Gorda                       1
# León                                         1
# Chavarría                                    1
# Guadalupe - Chepinque                        1
# Galería Zacatecas                            1
# Villa Unión - Mazatlán                       1
# Chipinque - El Obraje                        1
# El Obraje - San Luis Potosí                  1
# El Huejote                                   1
# Sanalona                                     1
# Becos                                        1
# Enrique Estrada                              1
# El Dique                                     1
# El Carrizal                                  1
# Juan Escutia                                 1
# Los Mochis                                   1
# Residencial Casa Blanca                      1
# La Bebelama de San Pedro                     1
# Los Ayales                                   1
# El Guayabo                                   1
# Lomas del Convento                           1
# El Sauz                                      1
# Cascadas San Antonio                         1
# Tachinolpa                                   1
# Cosalá                                       1
# Zacatecas - San Luis Potosí                  1
# Xalitla                                      1
# Chilitas                                     1
# Sain Alto - Vicente Guerrero                 1
# Guadalupe - Sain Alto                        1
# Pánfilo Natera                               1
# Susticacán                                   1
# Duarte                                       1
# Las Chilitas                                 1
# Joaquín Amaro                                1
# Valparaíso                                   1
# Las Puentes                                  1
# Culiacán centro                              1
# Paralelo 38                                  1
# Entronque Campo Victoria                     1
# Las Aguamitas                                1
# Hotel Riu                                    1
# Parque de la Revolución                      1
# Eldorado                                     1
# El Tule                                      1
# Guasave                                      1
# Capilla Malverde                             1
# El Vallado                                   1
# Industrial Penitenciaria                     1
# Penitenciaria                                1
# Soriana Zapata                               1
# Restaurante Narcisa                          1
# Sombrerete                                   1
# Parque Temático Militar                      1
# Cerrajería Forza                             1
# San Antonio de los Negros                    1
# Coatzacoalcos                                1
# Roca Partida                                 1
# Veracruz                                     1
# La Joya                                      1
# La Quemada                                   1
# Huitzuco                                     1
# Tlaltenango                                  1
# Bernal                                       1
# Palmillas                                    1
# Durango - Concordia                          1
# Santa Rosa Jauregui                          1
# Durango- La Ciudad                           1
# Centro Guadalupe                             1
# El Silencio                                  1
# Tránsito                                     1
# SAT                                          1
# Cerro Papanton                               1
# Malecón                                      1
# Bebelama de San Pedro                        1
# Quilá                                        1
# Arca Continental                             1
# Lo de Jesús                                  1
# Agua Blanca                                  1
# Bachigualatito                               1
# Econo llantas                                1
# Citicinemas La Isla                          1
# Musalá                                       1
# Colonia Michoacana                           1
# El Triguito                                  1
# Playa Ceuta                                  1
# Celestino Gazca                              1
# La Cruz Centro                               1
# La Cruz - Celestino Gazca                    1
# Entronque Villa Juárez                       1
# Panadería Flor de México                     1
# Caseta Cuauhémoc-Osiris                      1
# Parroquia La Sagrada Familia                 1
# El Castillo                                  1
# Concordia                                    1
# Mazatlán - La Cruz                           1
# La Cruz - Culiacán                           1
# Pueblos Unidos                               1
# Navolato Centro                              1
# Playa Humaya                                 1
# Jardín Botánico                              1
# Costa Azul                                   1
# Isla El Maviri                               1
# Topolobampo Malecón                          1
# Guamúchil Centro                             1
# Parque Culiacán 87                           1
# El Sifón                                     1
# Huizaches                                    1
# Lomas de Sotelo                              1
# La Condesa                                   1
# Copala - Potrerillos                         1
# Metro Normal                                 1
# Aguascalientes Centro                        1
# Waltmart                                     1
# Soriana Tres Cruces                          1
# Fracc. Dependencias Federales                1
# Muebles DICO                                 1
# Viñedos, Querétaro                           1
# Calle 6, Querétaro                           1
# Querétaro Centro                             1
# Conde de Santiago                            1
# Soriana Gavilanes                            1
# Durango Centro                               1
# Parque Ribieras                              1
# Mazatlán - Concordia                         1
# Colotlán                                     1
# Zóquite                                      1
# Tetillas                                     1
# Genaro Codina                                1
# San Ramón                                    1
# Santo Domingo - Real del Catorce             1
# Hacienda Nueva                               1
# Boulevard Emiliano Zapata                    1
# Superblock                                   1
# Parque Acuático Tres Ríos                    1
# Entronque a El Quemadito                     1
# Ley Del Valle                                1
# Bachigualatillo                              1
# Metro Pantitlán                              1
# Tenayuca                                     1
# Agencia Hyundai                              1
# Nochistlán - Tepatitlán                      1
# Calvillo - Nochistlán                        1
# Guadalupe - Calvillo                         1
# Chaparrosa                                   1
# Mezquitic - Moctezuma                        1
# Rincón de Romos - Mexquitic                  1
# San Pedro Ocotlán                            1
# Ciénaga de Villareales                       1
# Villas del Río                               1
# La Lomita                                    1
# El Barril                                    1
# La Palmita                                   1
# Mompaní                                      1
# Aguascalientes - San Juan de los Lagos       1
# Laguna Seca                                  1
# Parque México                                1
# Metro Popotla                                1
# Pánuco                                       1
# Los Ayala                                    1
# Rincón de Guayavitos                         1
# Metrobús Hospital La Raza                    1
# Ley Plaza Fiesta                             1
# Gasolinera                                   1
# Presa El Mastranto                           1
# Entronque a Villas del Río                   1
# La Palma                                     1
# Colonia Roma Norte                           1
# Metro Tacuba                                 1
# Metro Cuitláhuac                             1
# Cerro de la Estrella                         1
# Nueve Parroquias, CDMX                       1
# Name: count, dtype: int64

# %%
df1.loc[:,'Nombre de la actividad'] = dfact['Activity']
df1.tail()
# Out:
#       Id. de actividad Fecha de la actividad Nombre de la actividad  \
# 2618       15062070140   2025-07-09 00:00:00              Guadalupe
# 2619       15064232066   2025-07-10 00:00:00       Zacatecas Centro
# 2620       15082470006   2025-07-11 00:00:00               Nissan 2
# 2621       15091449603   2025-07-12 00:00:00     Presa El Mastranto
# 2622       15106139815   2025-07-13 00:00:00   Central de autobuses
#
#      Tipo de actividad Descripción de la actividad  Tiempo transcurrido  \
# 2618          Ciclismo                       Pagos                 5816
# 2619          Caminata                   Zacatecas                 8155
# 2620          Caminata              Aguascalientes                15918
# 2621          Ciclismo                         NaN                10109
# 2622          Ciclismo                   Zacatecas                 1464
#
#       Distancia  Ritmo cardíaco máx.  Esfuerzo relativo  Viaje al trabajo  \
# 2618      13.22                128.0                8.0             False
# 2619       7.22                110.0               14.0             False
# 2620      23.41                  NaN                NaN             False
# 2621      40.97                147.0               33.0             False
# 2622       5.14                152.0               20.0             False
#
#      Equipamiento de la actividad              Nombre de archivo  \
# 2618             Trek X-Caliber 9  activities/16080966128.fit.gz
# 2619       Adidas Terrex Eastrail  activities/16083343664.fit.gz
# 2620        Skechers Squad 232290     activities/15082470006.gpx
# 2621             Trek X-Caliber 9  activities/16113281376.fit.gz
# 2622             Trek X-Caliber 9  activities/16129436693.fit.gz
#
#       Peso de la bicicleta  Tiempo transcurrido.1  Tiempo en movimiento  \
# 2618                  14.5                 5816.0                3889.0
# 2619                   NaN                 8155.0                6694.0
# 2620                   NaN                15918.0               15511.0
# 2621                  14.5                10109.0                8651.0
# 2622                  14.5                 1464.0                1429.0
#
#        Distancia.1  Velocidad máxima  Velocidad promedio  Desnivel positivo  \
# 2618  13220.599609          8.600000            3.399486         118.358093
# 2619   7223.500000          4.663636            1.079101          87.697800
# 2620  23409.300781          7.160000            1.509206          83.825684
# 2621  40978.000000         11.530000            4.736794         366.537292
# 2622   5141.399902          7.920000            3.597901         174.076370
#
#       Desnivel negativo  Desnivel bajo  Desnivel alto  Grado máximo  \
# 2618         404.000000    2259.199951    2338.199951     21.348314
# 2619         847.000000    2313.199951    2441.000000     16.875000
# 2620          62.880806    1858.400024    1890.000000     39.393940
# 2621         502.000000    2238.000000    2480.199951     24.799999
# 2622         138.000000    2323.899902    2473.699951     31.250000
#
#       Pendiente promedio  Ritmo cardíaco promedio  Vatios promedio  \
# 2618            0.099844                89.400757        47.686947
# 2619           -0.944141                86.362045              NaN
# 2620            0.090562                      NaN              NaN
# 2621           -0.002196               105.381279        64.967407
# 2622            2.567394               133.165482       139.644913
#
#          Calorías  Esfuerzo relativo.1  Usar Esfuerzo Percibido  \
# 2618   334.000000                  8.0                      0.0
# 2619   551.000000                 14.0                      0.0
# 2620  2272.240479                  NaN                      0.0
# 2621   892.000000                 33.0                      0.0
# 2622   267.000000                 20.0                      0.0
#
#       Viaje al trabajo.1  De carga  Bicicleta  Marcado  \
# 2618                 0.0       1.0  5230367.0      0.0
# 2619                 0.0       1.0        NaN      0.0
# 2620                 0.0       1.0        NaN      0.0
# 2621                 0.0       1.0  5230367.0      0.0
# 2622                 0.0       1.0  5230367.0      0.0
#
#       Velocidad promedio durante el tiempo transcurrido  \
# 2618                                           2.273143
# 2619                                           0.885776
# 2620                                           1.470618
# 2621                                           4.053616
# 2622                                           3.511885
#
#       Distancia sobre tierra
# 2618             8472.799805
# 2619             2593.300049
# 2620             1224.599976
# 2621            13585.700195
# 2622             2839.899902

# %% [markdown]
# ## Clean Activity Description

# %%
# Copy 'Id. de actividad' y 'Descripción de la actividad' en un dataframe nuevo
dfact = df1[['Id. de actividad', 'Descripción de la actividad']].copy()
print(f"Dataframe shape: {dfact.shape}")
print(f"Non-empty rows: {(~dfact['Descripción de la actividad'].isnull()).sum()}")
dfact.head()
# Out:
# Dataframe shape: (2623, 2)
# Non-empty rows: 490
#    Id. de actividad Descripción de la actividad
# 0         353375734            Vuelta a la Bufa
# 1         353377512                         NaN
# 2         353380425               Tour Personal
# 3         353381733               Tour Personal
# 4         353384459               Tour Personal

# %%
# Identify the rows with 'Carrera' as the first word in 'Descripción de la actividad'. Define a
# new column 'Tipo rodada' and assign 'Carrera' to those rows.
dfact['Descripción de rodada'] = dfact['Descripción de la actividad'].str.split().str[0]
dfact['Tipo rodada'] = 'Vuelta'
dfact.loc[dfact['Descripción de rodada'] == 'Carrera', 'Tipo rodada'] = 'Carrera'
dfact.loc[dfact['Descripción de rodada'] == 'Tour', 'Tipo rodada'] = 'Tour'
dfact['Tipo rodada'].value_counts()
# Out:
# Tipo rodada
# Vuelta     2542
# Tour         58
# Carrera      23
# Name: count, dtype: int64

# %%
# Add the column 'Tipo rodada' to the dataframe df1
df1.loc[0:df1.shape[0],'Tipo rodada'] = dfact['Tipo rodada']
df1.head()
# Out:
# C:\Users\L01032102\AppData\Local\Temp\ipykernel_13144\2781453355.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[0:df1.shape[0],'Tipo rodada'] = dfact['Tipo rodada']
#    Id. de actividad Fecha de la actividad   Nombre de la actividad  \
# 0         353375734   2015-07-24 00:00:00                Zacatecas
# 1         353377512   2015-07-19 00:00:00                 Tepetate
# 2         353380425   2015-07-13 00:00:00  Nochistlán - Tepatitlán
# 3         353381733   2015-07-12 00:00:00    Calvillo - Nochistlán
# 4         353384459   2015-07-11 00:00:00     Guadalupe - Calvillo
#
#   Tipo de actividad Descripción de la actividad  Tiempo transcurrido  \
# 0          Ciclismo            Vuelta a la Bufa                 3069
# 1          Ciclismo                         NaN                22770
# 2          Ciclismo               Tour Personal                30131
# 3          Ciclismo               Tour Personal                41874
# 4          Ciclismo               Tour Personal                43152
#
#    Distancia  Ritmo cardíaco máx.  Esfuerzo relativo  Viaje al trabajo  \
# 0      14.33                  NaN                NaN             False
# 1      92.15                  NaN                NaN             False
# 2      98.53                  NaN                NaN             False
# 3     114.20                  NaN                NaN             False
# 4     151.96                  NaN                NaN             False
#
#   Equipamiento de la actividad            Nombre de archivo  \
# 0                    TREK 8500  activities/400134783.gpx.gz
# 1                    TREK 8500  activities/400136595.gpx.gz
# 2                    TREK 8500  activities/400139647.gpx.gz
# 3                    TREK 8500  activities/400140985.gpx.gz
# 4                    TREK 8500  activities/400143736.gpx.gz
#
#    Peso de la bicicleta  Tiempo transcurrido.1  Tiempo en movimiento  \
# 0                  16.0                 3069.0                3069.0
# 1                  16.0                22770.0               16473.0
# 2                  16.0                30131.0               19435.0
# 3                  16.0                41874.0               28662.0
# 4                  16.0                43152.0               30451.0
#
#      Distancia.1  Velocidad máxima  Velocidad promedio  Desnivel positivo  \
# 0   14330.299805              18.1                 NaN         406.476013
# 1   92158.398438              13.2                 NaN         791.320007
# 2   98532.398438              15.2                 NaN        1550.469971
# 3  114199.000000              15.2                 NaN        2102.399902
# 4  151961.000000              18.4                 NaN        1738.469971
#
#    Desnivel negativo  Desnivel bajo  Desnivel alto  Grado máximo  \
# 0         427.936951    2308.600098    2554.899902     26.900000
# 1         874.078064    2219.699951    2473.500000     21.000000
# 2        1744.161743    1453.300049    2091.800049     40.400002
# 3        2093.768555    1640.000000    2417.800049     39.200001
# 4        2602.712891    1640.000000    2455.100098     27.500000
#
#    Pendiente promedio  Ritmo cardíaco promedio  Vatios promedio     Calorías  \
# 0           -0.048150                      NaN       197.826767   676.950317
# 1           -0.002279                      NaN       166.551178  3059.111328
# 2           -0.117728                      NaN       169.094589  3664.292969
# 3            0.209809                      NaN       143.750061  4593.980957
# 4           -0.457881                      NaN       153.353729  5206.807617
#
#    Esfuerzo relativo.1  Usar Esfuerzo Percibido  Viaje al trabajo.1  De carga  \
# 0                  NaN                      0.0                 0.0       NaN
# 1                  NaN                      0.0                 0.0       NaN
# 2                  NaN                      0.0                 0.0       NaN
# 3                  NaN                      0.0                 0.0       NaN
# 4                  NaN                      0.0                 0.0       NaN
#
#    Bicicleta  Marcado  Velocidad promedio durante el tiempo transcurrido  \
# 0  2169839.0      NaN                                                NaN
# 1  2169839.0      NaN                                                NaN
# 2  2169839.0      NaN                                                NaN
# 3  2169839.0      NaN                                                NaN
# 4  2169839.0      NaN                                                NaN
#
#    Distancia sobre tierra Tipo rodada
# 0             7331.000000      Vuelta
# 1            20137.599609      Vuelta
# 2              785.599976        Tour
# 3            21528.099609        Tour
# 4            50302.500000        Tour

# %% [markdown]
# ## Make numeric columns

# %%
# Numeric columns
cols = ['Tiempo transcurrido', 'Distancia', 'Ritmo cardíaco máx.', 'Esfuerzo relativo', 'Peso de la bicicleta',
        'Tiempo en movimiento', 'Velocidad máxima', 'Velocidad promedio', 'Desnivel positivo', 'Desnivel negativo', 
        'Desnivel bajo', 'Desnivel alto', 'Grado máximo', 'Pendiente promedio','Ritmo cardíaco promedio', 
        'Vatios promedio', 'Calorías', 'Marcado', 'Velocidad promedio durante el tiempo transcurrido',
       'Distancia sobre tierra']
df = df1.drop(columns=['Tiempo transcurrido.1', 'Distancia.1', 'Esfuerzo relativo.1', 'Usar Esfuerzo Percibido',
                       'Viaje al trabajo.1', 'De carga', 'Bicicleta'])
# Convert to numeric
df.loc[:, cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df.head()
# Out:
#    Id. de actividad Fecha de la actividad   Nombre de la actividad  \
# 0         353375734   2015-07-24 00:00:00                Zacatecas
# 1         353377512   2015-07-19 00:00:00                 Tepetate
# 2         353380425   2015-07-13 00:00:00  Nochistlán - Tepatitlán
# 3         353381733   2015-07-12 00:00:00    Calvillo - Nochistlán
# 4         353384459   2015-07-11 00:00:00     Guadalupe - Calvillo
#
#   Tipo de actividad Descripción de la actividad  Tiempo transcurrido  \
# 0          Ciclismo            Vuelta a la Bufa                 3069
# 1          Ciclismo                         NaN                22770
# 2          Ciclismo               Tour Personal                30131
# 3          Ciclismo               Tour Personal                41874
# 4          Ciclismo               Tour Personal                43152
#
#    Distancia  Ritmo cardíaco máx.  Esfuerzo relativo  Viaje al trabajo  \
# 0      14.33                  NaN                NaN             False
# 1      92.15                  NaN                NaN             False
# 2      98.53                  NaN                NaN             False
# 3     114.20                  NaN                NaN             False
# 4     151.96                  NaN                NaN             False
#
#   Equipamiento de la actividad            Nombre de archivo  \
# 0                    TREK 8500  activities/400134783.gpx.gz
# 1                    TREK 8500  activities/400136595.gpx.gz
# 2                    TREK 8500  activities/400139647.gpx.gz
# 3                    TREK 8500  activities/400140985.gpx.gz
# 4                    TREK 8500  activities/400143736.gpx.gz
#
#    Peso de la bicicleta  Tiempo en movimiento  Velocidad máxima  \
# 0                  16.0                3069.0              18.1
# 1                  16.0               16473.0              13.2
# 2                  16.0               19435.0              15.2
# 3                  16.0               28662.0              15.2
# 4                  16.0               30451.0              18.4
#
#    Velocidad promedio  Desnivel positivo  Desnivel negativo  Desnivel bajo  \
# 0                 NaN         406.476013         427.936951    2308.600098
# 1                 NaN         791.320007         874.078064    2219.699951
# 2                 NaN        1550.469971        1744.161743    1453.300049
# 3                 NaN        2102.399902        2093.768555    1640.000000
# 4                 NaN        1738.469971        2602.712891    1640.000000
#
#    Desnivel alto  Grado máximo  Pendiente promedio  Ritmo cardíaco promedio  \
# 0    2554.899902     26.900000           -0.048150                      NaN
# 1    2473.500000     21.000000           -0.002279                      NaN
# 2    2091.800049     40.400002           -0.117728                      NaN
# 3    2417.800049     39.200001            0.209809                      NaN
# 4    2455.100098     27.500000           -0.457881                      NaN
#
#    Vatios promedio     Calorías  Marcado  \
# 0       197.826767   676.950317      NaN
# 1       166.551178  3059.111328      NaN
# 2       169.094589  3664.292969      NaN
# 3       143.750061  4593.980957      NaN
# 4       153.353729  5206.807617      NaN
#
#    Velocidad promedio durante el tiempo transcurrido  Distancia sobre tierra  \
# 0                                                NaN             7331.000000
# 1                                                NaN            20137.599609
# 2                                                NaN              785.599976
# 3                                                NaN            21528.099609
# 4                                                NaN            50302.500000
#
#   Tipo rodada
# 0      Vuelta
# 1      Vuelta
# 2        Tour
# 3        Tour
# 4        Tour

# %% [markdown]
# ## Save results

# %%
# Save the cleaned data to a new excel file
df.to_excel('../data/strava_ips.xlsx', index=False)
